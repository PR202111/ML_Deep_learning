# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from nnfs.datasets import vertical_data

# %%
vertical_data??
# Out:
# Signature: vertical_data(samples, classes)
# Docstring: <no docstring>
# Source:
# def create_data(samples, classes):
#     X = np.zeros((samples*classes, 2))
#     y = np.zeros(samples*classes, dtype='uint8')
#     for class_number in range(classes):
#         ix = range(samples*class_number, samples*(class_number+1))
#         X[ix] = np.c_[np.random.randn(samples)*.1 + (class_number)/3, np.random.randn(samples)*.1 + 0.5]
#         y[ix] = class_number
#     return X, y
# File:      /opt/homebrew/anaconda3/lib/python3.12/site-packages/nnfs/datasets/vertical.py
# Type:      function

# %%
x,y = vertical_data(samples = 300,classes = 3)

# %%
plt.scatter(x[:,0],x[:,1],c = y,cmap='brg')

# %%
class Dense:
    def __init__(self,no_of_inputs,no_of_neurons):
        self.no_of_inputs = no_of_inputs
        self.no_of_neurons = no_of_neurons
        self.weights = np.array(np.random.rand(self.no_of_inputs,self.no_of_neurons)) * 0.01
        self.bias = np.array(np.random.rand(1,self.no_of_neurons))

    def forward(self,inputs):
        self.output = inputs@self.weights + self.bias



class Activation_Relu:
    def forward(self,Dense_output):
        self.activation_output = np.maximum(0,Dense_output)


class Softmax:
    def forward(self,y_pred):
        y_pred = y_pred - np.max(y_pred,axis=1,keepdims=True)
        self.exp = np.exp(y_pred) 
        self.sum_rows = np.sum(self.exp,axis=1,keepdims=True)
        self.output = self.exp / self.sum_rows



class CrossEntropyLoss:
    def forward(self,y_pred,y_true):
        samples = len(y_pred)
        y_pred_clipped = np.clip(y_pred,1e-7,1-1e-7)
        if len(y_true.shape) == 1:
            self.output = -np.mean(np.log(y_pred[range(samples),y_true]))
        elif len(y_true.shape) == 2:
            self.output = -np.mean(np.log(np.sum(y_pred*y_true,axis=1)))

# %%
# x,y is our inputs for vertical Dataset
# creating the model

layer1 = Dense(2,3)
layer1_relu = Activation_Relu()
layer2 = Dense(3,3)
layer2_softmax = Softmax()

loss_function = CrossEntropyLoss()
lowest_loss = 999999
best_w_layer1 = layer1.weights.copy()
best_b_layer1 = layer1.bias.copy()
best_w_layer2 = layer2.weights.copy()
best_b_layer2 = layer2.bias.copy()

# %%
# staring the model for 100000 iterations
for iterations in range(100000):
    layer1.weights += 0.05*np.random.randn(2,3)
    layer1.bias += 0.05*np.random.randn(1,3)
    layer2.weights += 0.05*np.random.randn(3,3)
    layer2.bias += 0.05*np.random.randn(1,3)

    layer1.forward(x)
    layer1_relu.forward(layer1.output)
    layer2.forward(layer1_relu.activation_output)
    layer2_softmax.forward(layer2.output)

    loss_function.forward(layer2_softmax.output,y)

    if loss_function.output < lowest_loss:
        lowest_loss = loss_function.output
        prediction = np.argmax(layer2.output,axis=1)
        accuracy = np.mean(prediction == y)
        print(f"at iteration {iterations+1} loss = {loss_function.output} accuracy = {accuracy}")
        best_w_layer1 = layer1.weights.copy()
        best_b_layer1 = layer1.bias.copy()
        best_w_layer2 = layer2.weights.copy()
        best_b_layer2 = layer2.bias.copy()

    else:
        layer1.weights = best_w_layer1.copy()
        layer1.bias = best_b_layer1.copy()
        layer2.weights = best_w_layer2.copy()
        layer2.bias = best_b_layer2.copy()
# Out:
# at iteration 1 loss = 1.0998092182773858 accuracy = 0.3333333333333333
# at iteration 2 loss = 1.099414091172621 accuracy = 0.3333333333333333
# at iteration 3 loss = 1.0962314846469898 accuracy = 0.3333333333333333
# at iteration 5 loss = 1.0909351963050258 accuracy = 0.33444444444444443
# at iteration 7 loss = 1.088405710414743 accuracy = 0.3433333333333333
# at iteration 8 loss = 1.0857345368177824 accuracy = 0.3333333333333333
# at iteration 9 loss = 1.0831349445559095 accuracy = 0.43555555555555553
# at iteration 11 loss = 1.075942388708421 accuracy = 0.37333333333333335
# at iteration 13 loss = 1.0730455231683618 accuracy = 0.5611111111111111
# at iteration 15 loss = 1.072567140894759 accuracy = 0.43666666666666665
# at iteration 19 loss = 1.0655489669783158 accuracy = 0.7733333333333333
# at iteration 21 loss = 1.062305378545165 accuracy = 0.6655555555555556
# at iteration 22 loss = 1.0571987701252135 accuracy = 0.47888888888888886
# at iteration 23 loss = 1.0429966096695935 accuracy = 0.4577777777777778
# at iteration 24 loss = 1.0409246689037006 accuracy = 0.6777777777777778
# at iteration 26 loss = 1.0397224615492688 accuracy = 0.8755555555555555
# at iteration 30 loss = 1.0395460092908733 accuracy = 0.6066666666666667
# at iteration 32 loss = 1.0381233404098207 accuracy = 0.5866666666666667
# at iteration 35 loss = 1.0351084620514406 accuracy = 0.4066666666666667
# at iteration 36 loss = 1.0218838668168277 accuracy = 0.5922222222222222
# at iteration 38 loss = 1.0157209633297128 accuracy = 0.5077777777777778
# at iteration 45 loss = 1.0144998951837347 accuracy = 0.49444444444444446
# at iteration 46 loss = 1.0008710034110229 accuracy = 0.3433333333333333
# at iteration 47 loss = 0.9992893894715758 accuracy = 0.5188888888888888
# at iteration 56 loss = 0.9890657383015388 accuracy = 0.5222222222222223
# at iteration 57 loss = 0.9807029827347457 accuracy = 0.6466666666666666
# at iteration 63 loss = 0.9711079883502591 accuracy = 0.6533333333333333
# at iteration 64 loss = 0.951006156319814 accuracy = 0.6477777777777778
# at iteration 67 loss = 0.949873995460856 accuracy = 0.6111111111111112
# at iteration 70 loss = 0.9275701894446666 accuracy = 0.6233333333333333
# at iteration 73 loss = 0.9152745326836401 accuracy = 0.6522222222222223
# at iteration 79 loss = 0.9146541707325632 accuracy = 0.6655555555555556
# at iteration 80 loss = 0.9145062218577591 accuracy = 0.5977777777777777
# at iteration 81 loss = 0.9118415094166875 accuracy = 0.6844444444444444
# at iteration 83 loss = 0.909159781912928 accuracy = 0.7777777777777778
# at iteration 85 loss = 0.9060568726596203 accuracy = 0.61
# at iteration 90 loss = 0.904106706509034 accuracy = 0.5988888888888889
# at iteration 95 loss = 0.8962533804785369 accuracy = 0.7222222222222222
# at iteration 96 loss = 0.8946405005661621 accuracy = 0.6666666666666666
# at iteration 98 loss = 0.8806655229175221 accuracy = 0.6988888888888889
# at iteration 100 loss = 0.8725687137494874 accuracy = 0.6788888888888889
# at iteration 105 loss = 0.8687244788749775 accuracy = 0.66
# at iteration 106 loss = 0.8601131914539386 accuracy = 0.7222222222222222
# at iteration 108 loss = 0.8520675008658674 accuracy = 0.7577777777777778
# at iteration 110 loss = 0.8455270433044431 accuracy = 0.7311111111111112
# at iteration 113 loss = 0.8359412066488795 accuracy = 0.6244444444444445
# at iteration 115 loss = 0.8204767500371275 accuracy = 0.8355555555555556
# at iteration 122 loss = 0.8152024719583182 accuracy = 0.6788888888888889
# at iteration 125 loss = 0.801297997355866 accuracy = 0.7055555555555556
# at iteration 130 loss = 0.7848433944992249 accuracy = 0.7011111111111111
# at iteration 133 loss = 0.7811637461593924 accuracy = 0.6933333333333334
# at iteration 143 loss = 0.7723787623651007 accuracy = 0.6788888888888889
# at iteration 150 loss = 0.7660049039408817 accuracy = 0.6655555555555556
# at iteration 155 loss = 0.7509726274883843 accuracy = 0.6844444444444444
# at iteration 156 loss = 0.744611748747891 accuracy = 0.7066666666666667
# at iteration 161 loss = 0.7367872164339428 accuracy = 0.7377777777777778
# at iteration 163 loss = 0.7249711605636079 accuracy = 0.6977777777777778
# at iteration 164 loss = 0.7051108037427094 accuracy = 0.8333333333333334
# at iteration 167 loss = 0.7041457425091572 accuracy = 0.8611111111111112
# at iteration 170 loss = 0.7003435128042124 accuracy = 0.8311111111111111
# at iteration 171 loss = 0.6984127522252748 accuracy = 0.7344444444444445
# at iteration 173 loss = 0.6951493485455712 accuracy = 0.6833333333333333
# at iteration 174 loss = 0.6862098959879196 accuracy = 0.6944444444444444
# at iteration 177 loss = 0.678768732675756 accuracy = 0.8266666666666667
# at iteration 180 loss = 0.6757529609956119 accuracy = 0.8822222222222222
# at iteration 184 loss = 0.6611242275281586 accuracy = 0.8733333333333333
# at iteration 189 loss = 0.6608226878085035 accuracy = 0.8533333333333334
# at iteration 191 loss = 0.6470531909164412 accuracy = 0.7388888888888889
# at iteration 193 loss = 0.6286832393406527 accuracy = 0.8377777777777777
# at iteration 195 loss = 0.6221425535672539 accuracy = 0.8688888888888889
# at iteration 200 loss = 0.6202592117716738 accuracy = 0.7911111111111111
# at iteration 202 loss = 0.604569783366014 accuracy = 0.87
# at iteration 203 loss = 0.5791337197937292 accuracy = 0.9011111111111111
# at iteration 204 loss = 0.5666266450274116 accuracy = 0.9233333333333333
# at iteration 211 loss = 0.5635640837732139 accuracy = 0.9211111111111111
# at iteration 212 loss = 0.5594344565371315 accuracy = 0.93
# at iteration 215 loss = 0.5500699961664242 accuracy = 0.9255555555555556
# at iteration 222 loss = 0.5456940006392638 accuracy = 0.9155555555555556
# at iteration 224 loss = 0.5449110114121374 accuracy = 0.9044444444444445
# at iteration 227 loss = 0.5420700882197499 accuracy = 0.8911111111111111
# at iteration 231 loss = 0.5412043849303902 accuracy = 0.8933333333333333
# at iteration 232 loss = 0.5355901389556397 accuracy = 0.8888888888888888
# at iteration 233 loss = 0.5308510444550402 accuracy = 0.8977777777777778
# at iteration 234 loss = 0.5307803558463285 accuracy = 0.9322222222222222
# at iteration 236 loss = 0.5275201807946849 accuracy = 0.8966666666666666
# at iteration 245 loss = 0.5189687418960854 accuracy = 0.9022222222222223
# at iteration 248 loss = 0.5131345255773395 accuracy = 0.9177777777777778
# at iteration 249 loss = 0.5060423279477221 accuracy = 0.8722222222222222
# at iteration 252 loss = 0.5020001553749882 accuracy = 0.8722222222222222
# at iteration 257 loss = 0.48466114568369956 accuracy = 0.9144444444444444
# at iteration 265 loss = 0.4840848487079696 accuracy = 0.93
# at iteration 266 loss = 0.47712191115201524 accuracy = 0.9222222222222223
# at iteration 270 loss = 0.47418625021678645 accuracy = 0.9244444444444444
# at iteration 271 loss = 0.4653166078938173 accuracy = 0.9288888888888889
# at iteration 276 loss = 0.45529685971269473 accuracy = 0.9244444444444444
# at iteration 279 loss = 0.44994465111429205 accuracy = 0.9277777777777778
# at iteration 282 loss = 0.4476034278847427 accuracy = 0.9288888888888889
# at iteration 290 loss = 0.4473748844973647 accuracy = 0.9322222222222222
# at iteration 292 loss = 0.44427047801313657 accuracy = 0.9288888888888889
# at iteration 293 loss = 0.43678412608497125 accuracy = 0.9088888888888889
# at iteration 298 loss = 0.42699952118672296 accuracy = 0.9222222222222223
# at iteration 299 loss = 0.42330610254324397 accuracy = 0.9166666666666666
# at iteration 303 loss = 0.41635376440331395 accuracy = 0.9322222222222222
# at iteration 305 loss = 0.4121908410538662 accuracy = 0.9277777777777778
# at iteration 307 loss = 0.4121216496159459 accuracy = 0.93
# at iteration 312 loss = 0.4053953212281133 accuracy = 0.9277777777777778
# at iteration 315 loss = 0.39781647447150575 accuracy = 0.9288888888888889
# at iteration 321 loss = 0.3922843153382033 accuracy = 0.9277777777777778
# at iteration 335 loss = 0.3863922591597268 accuracy = 0.9311111111111111
# at iteration 341 loss = 0.38589323478783916 accuracy = 0.93
# at iteration 343 loss = 0.3824467904149612 accuracy = 0.9311111111111111
# at iteration 346 loss = 0.37899211821543966 accuracy = 0.93
# at iteration 347 loss = 0.37617392283038764 accuracy = 0.9133333333333333
# at iteration 350 loss = 0.36495173533242575 accuracy = 0.9322222222222222
# at iteration 353 loss = 0.36345555012134495 accuracy = 0.9311111111111111
# at iteration 354 loss = 0.3615151775031131 accuracy = 0.9266666666666666
# at iteration 359 loss = 0.3613307944847947 accuracy = 0.93
# at iteration 362 loss = 0.36070250103429524 accuracy = 0.9288888888888889
# at iteration 364 loss = 0.3602866094717892 accuracy = 0.9311111111111111
# at iteration 366 loss = 0.3567206305383138 accuracy = 0.9288888888888889
# at iteration 368 loss = 0.3549820444166937 accuracy = 0.9166666666666666
# at iteration 369 loss = 0.3495149160883349 accuracy = 0.9288888888888889
# at iteration 371 loss = 0.34769512876223435 accuracy = 0.92
# at iteration 374 loss = 0.34309390016572267 accuracy = 0.9211111111111111
# at iteration 377 loss = 0.3386588098966857 accuracy = 0.9166666666666666
# at iteration 378 loss = 0.3338535762561332 accuracy = 0.9155555555555556
# at iteration 380 loss = 0.3319846038754734 accuracy = 0.93
# at iteration 387 loss = 0.32523873468405323 accuracy = 0.9333333333333333
# at iteration 396 loss = 0.31818981188220025 accuracy = 0.93
# at iteration 397 loss = 0.31418531738809646 accuracy = 0.93
# at iteration 399 loss = 0.3089763626341956 accuracy = 0.9277777777777778
# at iteration 401 loss = 0.3087947727563132 accuracy = 0.93
# at iteration 413 loss = 0.303455832278757 accuracy = 0.9288888888888889
# at iteration 418 loss = 0.2899685607934991 accuracy = 0.9266666666666666
# at iteration 425 loss = 0.28929796313970135 accuracy = 0.9277777777777778
# at iteration 434 loss = 0.28785833152375856 accuracy = 0.9277777777777778
# at iteration 444 loss = 0.2835630677131751 accuracy = 0.9266666666666666
# at iteration 446 loss = 0.2814443913544109 accuracy = 0.9288888888888889
# at iteration 450 loss = 0.27520648435319583 accuracy = 0.93
# at iteration 451 loss = 0.27376199368313714 accuracy = 0.93
# at iteration 454 loss = 0.2696896693669831 accuracy = 0.9333333333333333
# at iteration 459 loss = 0.26641057073534885 accuracy = 0.9311111111111111
# at iteration 468 loss = 0.2642068639688664 accuracy = 0.9277777777777778
# at iteration 470 loss = 0.26257093075839893 accuracy = 0.9277777777777778
# at iteration 471 loss = 0.2551343058316763 accuracy = 0.9266666666666666
# at iteration 483 loss = 0.24879354529484285 accuracy = 0.9277777777777778
# at iteration 491 loss = 0.24879225215006873 accuracy = 0.93
# at iteration 503 loss = 0.2482809826465073 accuracy = 0.93
# at iteration 505 loss = 0.24160530428978316 accuracy = 0.9288888888888889
# at iteration 510 loss = 0.23716855194621164 accuracy = 0.9288888888888889
# at iteration 520 loss = 0.2357396433808825 accuracy = 0.93
# at iteration 527 loss = 0.23482321502966663 accuracy = 0.9277777777777778
# at iteration 530 loss = 0.23075245836743927 accuracy = 0.9311111111111111
# at iteration 531 loss = 0.22860136778733128 accuracy = 0.9277777777777778
# at iteration 532 loss = 0.22739727303920707 accuracy = 0.9288888888888889
# at iteration 540 loss = 0.2235802637951575 accuracy = 0.9266666666666666
# at iteration 541 loss = 0.2214895081698534 accuracy = 0.9288888888888889
# at iteration 544 loss = 0.22077658158130306 accuracy = 0.9266666666666666
# at iteration 553 loss = 0.2195727430971456 accuracy = 0.9266666666666666
# at iteration 555 loss = 0.21815275413550012 accuracy = 0.9266666666666666
# at iteration 565 loss = 0.21780104142130252 accuracy = 0.9277777777777778
# at iteration 568 loss = 0.21578337823740254 accuracy = 0.9288888888888889
# at iteration 573 loss = 0.21568894007968062 accuracy = 0.9288888888888889
# at iteration 581 loss = 0.2154750618684258 accuracy = 0.9277777777777778
# at iteration 586 loss = 0.21461237205600228 accuracy = 0.93
# at iteration 587 loss = 0.21351393602534907 accuracy = 0.9311111111111111
# at iteration 600 loss = 0.21111074474002411 accuracy = 0.9266666666666666
# at iteration 610 loss = 0.2098065892518428 accuracy = 0.93
# at iteration 611 loss = 0.2085279200588448 accuracy = 0.9277777777777778
# at iteration 632 loss = 0.20662270666458676 accuracy = 0.9311111111111111
# at iteration 634 loss = 0.20652468550942507 accuracy = 0.9266666666666666
# at iteration 643 loss = 0.20402361175254521 accuracy = 0.9244444444444444
# at iteration 692 loss = 0.20326469347184659 accuracy = 0.9288888888888889
# at iteration 700 loss = 0.20055080289094024 accuracy = 0.9255555555555556
# at iteration 702 loss = 0.19991269365366704 accuracy = 0.9277777777777778
# at iteration 713 loss = 0.19730959930497546 accuracy = 0.9288888888888889
# at iteration 714 loss = 0.19679987870943405 accuracy = 0.9266666666666666
# at iteration 716 loss = 0.1944580144220628 accuracy = 0.9266666666666666
# at iteration 719 loss = 0.19289758411848293 accuracy = 0.9322222222222222
# at iteration 720 loss = 0.1924280897159023 accuracy = 0.9288888888888889
# at iteration 729 loss = 0.190390404922588 accuracy = 0.9311111111111111
# at iteration 739 loss = 0.1899413749937721 accuracy = 0.9288888888888889
# at iteration 741 loss = 0.18881781975857395 accuracy = 0.93
# at iteration 754 loss = 0.1887526987837281 accuracy = 0.93
# at iteration 768 loss = 0.18713234359946762 accuracy = 0.93
# at iteration 779 loss = 0.18638359446572084 accuracy = 0.9311111111111111
# at iteration 783 loss = 0.18338683728486166 accuracy = 0.9322222222222222
# at iteration 792 loss = 0.1820272317630053 accuracy = 0.93
# at iteration 796 loss = 0.18192973346066946 accuracy = 0.9288888888888889
# at iteration 852 loss = 0.18178233776823102 accuracy = 0.93
# at iteration 853 loss = 0.18122174168183303 accuracy = 0.9322222222222222
# at iteration 864 loss = 0.180941497907672 accuracy = 0.9322222222222222
# at iteration 866 loss = 0.18089764662911095 accuracy = 0.9311111111111111
# at iteration 867 loss = 0.18062902056919763 accuracy = 0.9266666666666666
# at iteration 882 loss = 0.17821237820994681 accuracy = 0.9311111111111111
# at iteration 926 loss = 0.17776754793698635 accuracy = 0.93
# at iteration 1013 loss = 0.17768992697693148 accuracy = 0.9311111111111111
# at iteration 1034 loss = 0.17694101671309043 accuracy = 0.93
# at iteration 1046 loss = 0.17581912246881487 accuracy = 0.9288888888888889
# at iteration 1051 loss = 0.17401572258903056 accuracy = 0.9288888888888889
# at iteration 1056 loss = 0.17391708542963172 accuracy = 0.93
# at iteration 1068 loss = 0.17260810588179967 accuracy = 0.9288888888888889
# at iteration 1088 loss = 0.17168113763237727 accuracy = 0.93
# at iteration 1093 loss = 0.1711321306243578 accuracy = 0.9288888888888889
# at iteration 1112 loss = 0.17075615847351924 accuracy = 0.9288888888888889
# at iteration 1125 loss = 0.16967182671939546 accuracy = 0.9277777777777778
# at iteration 1134 loss = 0.1696265528681595 accuracy = 0.9288888888888889
# at iteration 1135 loss = 0.16943752345396865 accuracy = 0.9266666666666666
# at iteration 1147 loss = 0.16929130711975018 accuracy = 0.9277777777777778
# at iteration 1148 loss = 0.16922734210835175 accuracy = 0.9277777777777778
# at iteration 1165 loss = 0.16878507017311575 accuracy = 0.9311111111111111
# at iteration 1180 loss = 0.16859593898127212 accuracy = 0.93
# at iteration 1182 loss = 0.16843883926707442 accuracy = 0.9311111111111111
# at iteration 1183 loss = 0.1680236129691596 accuracy = 0.9311111111111111
# at iteration 1201 loss = 0.1679684440544046 accuracy = 0.93
# at iteration 1207 loss = 0.1673603966550772 accuracy = 0.9277777777777778
# at iteration 1219 loss = 0.1670994494762358 accuracy = 0.9322222222222222
# at iteration 1224 loss = 0.16674133420975257 accuracy = 0.93
# at iteration 1225 loss = 0.1655233518305835 accuracy = 0.93
# at iteration 1240 loss = 0.16516581873102545 accuracy = 0.9266666666666666
# at iteration 1241 loss = 0.16502719998153756 accuracy = 0.9277777777777778
# at iteration 1254 loss = 0.16463558475149923 accuracy = 0.9288888888888889
# at iteration 1280 loss = 0.16446920263150977 accuracy = 0.9322222222222222
# at iteration 1291 loss = 0.1639721929135518 accuracy = 0.9288888888888889
# at iteration 1304 loss = 0.1634103520652754 accuracy = 0.9288888888888889
# at iteration 1406 loss = 0.16336805006317182 accuracy = 0.9288888888888889
# at iteration 1409 loss = 0.16280431953475924 accuracy = 0.9288888888888889
# at iteration 1423 loss = 0.16230397836680874 accuracy = 0.9277777777777778
# at iteration 1448 loss = 0.16229084912588185 accuracy = 0.9288888888888889
# at iteration 1457 loss = 0.16219052646294377 accuracy = 0.93
# at iteration 1465 loss = 0.16206205168717108 accuracy = 0.9288888888888889
# at iteration 1532 loss = 0.16194379820640412 accuracy = 0.9266666666666666
# at iteration 1607 loss = 0.1619432846916962 accuracy = 0.93
# at iteration 1669 loss = 0.1617619121969992 accuracy = 0.93
# at iteration 1675 loss = 0.16174233515851258 accuracy = 0.9288888888888889
# at iteration 1740 loss = 0.16161532207854884 accuracy = 0.93
# at iteration 1741 loss = 0.16144313315494602 accuracy = 0.9288888888888889
# at iteration 1833 loss = 0.1612212582447318 accuracy = 0.9277777777777778
# at iteration 1834 loss = 0.16118905031078845 accuracy = 0.9277777777777778
# at iteration 1836 loss = 0.16103298531051913 accuracy = 0.9277777777777778
# at iteration 1865 loss = 0.16091513952027867 accuracy = 0.9288888888888889
# at iteration 1879 loss = 0.16090984440218056 accuracy = 0.9277777777777778
# at iteration 1920 loss = 0.1608330419615204 accuracy = 0.93
# at iteration 1929 loss = 0.1607846686363454 accuracy = 0.9266666666666666
# at iteration 1943 loss = 0.16063834395784665 accuracy = 0.93
# at iteration 1949 loss = 0.16055884732474326 accuracy = 0.93
# at iteration 1973 loss = 0.1604323340489058 accuracy = 0.9277777777777778
# at iteration 2123 loss = 0.16041204102215714 accuracy = 0.93
# at iteration 2155 loss = 0.16038445909811566 accuracy = 0.9288888888888889
# at iteration 2164 loss = 0.16028004135915833 accuracy = 0.9288888888888889
# at iteration 2171 loss = 0.16018513298224535 accuracy = 0.9311111111111111
# at iteration 2201 loss = 0.16001996349788508 accuracy = 0.93
# at iteration 2304 loss = 0.15994540977119248 accuracy = 0.9288888888888889
# at iteration 2492 loss = 0.15986704168992408 accuracy = 0.9288888888888889
# at iteration 2508 loss = 0.15985437871950783 accuracy = 0.9288888888888889
# at iteration 2841 loss = 0.15985048793235776 accuracy = 0.9288888888888889
# at iteration 2859 loss = 0.1598416137060902 accuracy = 0.93
# at iteration 3265 loss = 0.1598296151898149 accuracy = 0.93
# at iteration 3388 loss = 0.15978047053785455 accuracy = 0.93
# at iteration 5033 loss = 0.15975560693772348 accuracy = 0.9288888888888889
# at iteration 5682 loss = 0.1597464297636656 accuracy = 0.93
# at iteration 6136 loss = 0.15974452871679698 accuracy = 0.93
# at iteration 8140 loss = 0.15973437825615822 accuracy = 0.93
# at iteration 9399 loss = 0.1597327007129362 accuracy = 0.93
# at iteration 9460 loss = 0.1597057595356102 accuracy = 0.9288888888888889
# at iteration 11945 loss = 0.15967622704932333 accuracy = 0.9311111111111111
# at iteration 19371 loss = 0.15966872786818695 accuracy = 0.93
# at iteration 20461 loss = 0.15966053440376093 accuracy = 0.93
# at iteration 24942 loss = 0.1596528343741895 accuracy = 0.93
# at iteration 24973 loss = 0.15961819102511532 accuracy = 0.93
# at iteration 33059 loss = 0.15961032477928902 accuracy = 0.93
# at iteration 35037 loss = 0.15960342599967148 accuracy = 0.9288888888888889
# at iteration 39339 loss = 0.1595982492224679 accuracy = 0.93
# at iteration 41914 loss = 0.15958087337837337 accuracy = 0.93
# at iteration 43926 loss = 0.1595716874349689 accuracy = 0.93
# at iteration 51169 loss = 0.15955990003809226 accuracy = 0.93
# at iteration 86877 loss = 0.1595294602565158 accuracy = 0.93
# at iteration 90239 loss = 0.1595083431421821 accuracy = 0.9288888888888889
# at iteration 97986 loss = 0.15949449548334446 accuracy = 0.93

# %% [markdown]
# Thsis Stratergy only works on simpler datasets it wont work on spiral datasets
